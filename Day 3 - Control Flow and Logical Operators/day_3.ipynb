# %% [markdown]
# # Day 3
# Control FLow and Logical Operators

# %% [markdown]
# #### Odd or Even

# %%
# input the number
number = int(input())

# calculate number modulo
if number % 2 == 0:
  print(number, "is an even number.")
else :
  print(number, "is an odd number")
# Out:
# 15 is an odd number

# %% [markdown]
# #### BMI Calculator

# %%
# input height and weight 
h = float(input("Insert your height in meters"))
w = float(input("Insert your weight in kg"))

# Calculate BMI
bmi = w/(h**2)

# BMI value interpreter
if bmi < 18.5 :
  print("Your BMI is {:.2f} you are underweight".format(bmi))
elif 18.5 <= bmi < 25 :
  print("Your BMI is {:.2f} you have a normal weight".format(bmi))
elif 25 <= bmi < 30 :
  print("Your BMI is {:.2f} you are slightly overweight".format(bmi))
elif 30 <= bmi < 35 :
  print("Your BMI is {:.2f} you are obese".format(bmi))
elif bmi > 30 :
  print("Your BMI is {:.2f} you are clinically obese".format(bmi))
# Out:
# Your BMI is 18.93 you have a normal weight

# %% [markdown]
# #### Leap Year

# %%
# Input year
y = int(input("Input year "))

# calclate leap year
if y % 4 == 0 :
  if y % 100 == 0 :
    if y % 400 == 0 :
      print(y, " is a leap year")
    else :
      print(y, " is not a leap year")
  else :
    print(y, "is a leap year")
else :
  print(y, "is not a leap year")
# Out:
# 2400  is a leap year

# %% [markdown]
# #### Pizza Order

# %%
# initial input
print("Thank you for choosing Python Pizza Deliveries!")
size = input("Please input your pizza size (S, M, L)")
add_pepperoni = input("Do you want to add pepperoni into your pizza? (Y or N)")
extra_cheese = input("Do you want extra cheese? (Y or N)")

# Pizza price calculation
if size=="S" :
  price = 15
  if add_pepperoni=="Y" : 
    price += 2
  if extra_cheese=="Y" :
    price += 1
elif size=="M" :
  price = 20
  if add_pepperoni=="Y" : 
    price += 3
  if extra_cheese=="Y" :
    price += 1
elif size=="L" :
  price = 25
  if add_pepperoni=="Y" : 
    price += 3
  if extra_cheese=="Y" :
    price += 1
    
print("Your total ordes is ${}".format(price))
# Out:
# Thank you for choosing Python Pizza Deliveries!
# Your total ordes is $24

# %% [markdown]
# #### Love Calculator

# %%
#Input name
name1 = input("Input first name :")
name2 = input("Input second name :")

# Check occurance
combined = name1 + name2
lower_name = combined.lower()
t = lower_name.count("t")
r = lower_name.count("r")
u = lower_name.count("u")
e = lower_name.count("e")
first_digit = t+r+u+e
l = lower_name.count("l")
o = lower_name.count("o")
v = lower_name.count("v")
e2 = lower_name.count("e")
second_digit = l+o+v+e2
score = int(str(first_digit)+str(second_digit))

# intreperter
if score < 10 & score > 90 :
  print(" your score is {}, you go together like coke and mentos.".format(score))
elif 40 < score < 50 :
  print(" your score is {}, you are alright together.".format(score))
else :
  print(" your score is {}.".format(score))
# Out:
#  your score is 42, you are alright together.

# %% [markdown]
# #### Zombe Apocalypse

# %%
print("""              
          _,-""-._
        ,"        ".
       /    ,-,  ,".
      "    /   \ | o|
      \    `-o-"  `-',
       `,   _.--'`'--`
         `--`---'     ___  ___  _____  ____  _  ___
           ,' '      |__ // _ \/ . , \|  __\| |/ -_)
          / ,  `,    /___|\___/|_|_|_||_.__/|_|\___|
         / /     |
        (_)))_ _,"
           _))))_,
  --------(_,-._)))-------------------------------""""") # art by n4bis 

print("\n")
print("You are a survivor of a zombie apocalype in your town.")
print("Your mission is to reach the save zone.")

# game start
print("You're currently hiding in your house, but your supplies is running low.")
print("A recent radio broadcast indicate there is a safe zone nearby.")
print("You decided to pack your belongings and proceed to start your journey to the safe house.")
print("After a few minutes, the road branch to right and left. Which way do you choose?")

road = input("right or left?")
if road=="right" :
  print("You decided follow the right road and continue your journey. \n")
  game = 1
elif road=="left" :
  print("You decided follow the left road and continue your journey.")
  print("Not long after that, you encounter a big mall.")
  print("Suddenly, a huge horde of zombies appear from inside the mall.")
  print("you run as fast as you can, however the horde manage to catch up with you.")
  print("GAME OVER")
  print("BAD END")
  game = 0
else :
  print("You stop for a while and rethink your decision.")
  print('"Do i want to continue this? Is it worht the effort?"')
  print("You keep thinking for 10 minutes.")
  print("Finnaly you decided to return to youre home.")
  print("You decided to remain hidden in your home and you let fate decided your future.")
  print("GAME OVER")
  print('??? END')
  game = 1
  
print("Later you found a motorway, however there are a bunch of zombies in the motor way")
print("You can try to outrun the zombies or try to sneak around the zombies.")

motorway = input("run or sneak")
if motorway == "run" and game ==1:
  print("You decided to run as fast as you can.")
  print("The zombies sees you running and chase after you.")
  print("Suddenly a car appear in fornt of you.")
  print("You did not react fast enough and got hit by the car.")
  print("GAME OVER")
  print("BAD END")
  game = 0
elif motorway == "sneak" and game ==1:
  print("You decided to sneak your way around the zombies.")
  print("Suddenly a car emerge from the distance.")
  print("The car alerted every zombies nearby, and the one near you is not an exception.")
  print("The zombies near you decided to chase after you.")
  print("You're not ready for the chase and the zombie manage to catch you.")
  print("GAME OVER")
  print("BAD END")
  game = 0
elif game == 1:
  print("You decided to remain quiet and not move at all.\n")
  game = 1

print("Suddenly, you can hear a car coming from the distance.")
print("The car bashed trough many zombies and send them flying.")
print("You let the car drive away and cross the motorway.")
print("You arrive in a dense forrest, the save zone is not far away.")
print("After walking for a while, you realized that you lost your way.")
print("You take out your compass, you can continue either north, northwest, or northeast.")
print("Wich way do you choose?\n")

forest = input("N,NW, or NE")
if forest == "N" and game ==1:
  print("You decided to continue north.")
  print("You can hear many zombies rustling between bushes nearby.")
  print("Slowly but surely you keep moving.")
  print("After an hour, you finnaly exit the forest.")
  print("In front of you is where your destination is.")
  print("The save zone, heavily guarded, and a hope for the survivors.")
  print("You approach the front gate and the guards sees you.")
  print("They proceed to check on you and take your blood samples.")
  print("Not long after that, the test result came out and you're considered free form the infection.")
  print("The guard open the gate and you enter the safe room.")
  print("GAME OVER")
  print("GOOD END")
elif forest=="NW" and game==1:
  print("You decided to continue northwest.")
  print("suddenly you end up between a horde of zombies")
  print("GAME OVER")
  print("BAD END")
elif forest=="NE" and game==1:
  print("You decided to continue northeast.")
  print("suddenly you end up between a horde of zombies")
  print("GAME OVER")
  print("BAD END")
elif game == 1:
  print("You decided to return where you came from.")
  print("You hear gun fire nearby.")
  print("You decided to approach the gun fire.")
  print("Suddenly a bullet hit you.")
  print("You fell on the ground in pain.")
  print("A group of men approach you.")
  print("You can't hear what are they talking but you knew the're laughing at you.")
  print("They take all of your belongings and leafe you behing.")
  print("GAME OVER")
  print("BAD END")
# Out:
#
#           _,-""-._
#         ,"        ".
#        /    ,-,  ,".
#       "    /   \ | o|
#       \    `-o-"  `-',
#        `,   _.--'`'--`
#          `--`---'     ___  ___  _____  ____  _  ___
#            ,' '      |__ // _ \/ . , \|  __\| |/ -_)
#           / ,  `,    /___|\___/|_|_|_||_.__/|_|\___|
#          / /     |
#         (_)))_ _,"
#            _))))_,
#   --------(_,-._)))-------------------------------
#
#
# You are a survivor of a zombie apocalype in your town.
# Your mission is to reach the save zone.
# You're currently hiding in your house, but your supplies is running low.
# A recent radio broadcast indicate there is a safe zone nearby.
# You decided to pack your belongings and proceed to start your journey to the safe house.
# After a few minutes, the road branch to right and left. Which way do you choose?
# You decided follow the right road and continue your journey.
#
# Later you found a motorway, however there are a bunch of zombies in the motor way
# ...
